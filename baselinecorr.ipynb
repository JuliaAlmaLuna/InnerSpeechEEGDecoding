# %%
import dataLoader as dl
import matplotlib.pyplot as plt



sub = 1
bdata, blabels = dl.load_data("baseline", sampling_rate=256, subject_nr=sub, t_start=0, t_end=15, verbose=True)
bdataEEG = bdata[:, :128]
bdataEEG.shape
blabels.shape # Basically not needed
# Out:
# Data shape: [trials x channels x samples]
# (3, 137, 3840)
# Labels shape
# (500, 4)
# Final data shape
# (3, 137, 3840)
# Final labels shape
# (500, 4)
# Up is 0 and Down is 1
# (500, 4)

# %%
print(blabels)
# Out:
# [[ 39869      3      0      1]
#  [ 46491      0      0      1]
#  [ 53010      3      0      1]
#  ...
#  [904589      1      2      3]
#  [911381      3      2      3]
#  [917764      3      2      3]]

# %%
bdata.shape # Day, channels ( inluding EMG, so remove last 9?) Should be 138 and remove 8
# Last channels seems empty, useless so remove as well. Donno what it is.
# Out:
# (3, 137, 3840)

# %%
# Out:
# (3, 128, 3840)

# %%
for x in range(1):
    plt.figure()
    plt.plot(bdata[1,131+x])
